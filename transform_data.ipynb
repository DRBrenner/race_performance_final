# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import requests
from config import password
from sqlalchemy import create_engine
print(password)
# Out:
# postgres

# %%
#Grab database
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/runner_data')
connection = engine.connect()

# %%
#Import data into pandas dataframes

log_df = pd.read_sql('select * from mini_training_log',connection)
log_df.head()
# Out:
#         id    log_date  runir_id  effort_num  feel_num
# 0   925562  2019-08-06     94511           5         1
# 1   992065  2019-08-02     95176           5         3
# 2  1257692  2019-08-24    117851           5         5
# 3  1275415  2019-08-07    118151           5         4
# 4  1261164  2019-08-12    117897           5         4

# %%
# Change misnamed "runir_id" to "runr_id"
log_df = log_df.rename(columns = {"runir_id":"runr_id"})
log_df.head(5)
# Out:
#         id    log_date  runr_id  effort_num  feel_num
# 0   925562  2019-08-06    94511           5         1
# 1   992065  2019-08-02    95176           5         3
# 2  1257692  2019-08-24   117851           5         5
# 3  1275415  2019-08-07   118151           5         4
# 4  1261164  2019-08-12   117897           5         4

# %%
results_df = pd.read_sql('select * from test_results_and_goals',connection)
results_df
# Out:
#            id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 0      264126  2018-09-08    93505       1068      b       117810   132000
# 1      264137  2018-08-17    93505       1068      b        83900    90400
# 2      268859  2018-09-17    94440       1134      b       158302   145800
# 3      268862  2018-09-11    94440       1134      b       165330   140800
# 4      268870  2018-10-02    94440       1134      b       145560    86500
# 5      269038  2018-09-22    94452       1140      b       127020   122190
# 6      269386  2018-09-25    94511        950      b        69410    85120
# 7      269387  2018-09-29    94511        950      b       103380   103380
# 8      269392  2018-10-02    94511        950      b       100880   107890
# 9      269393  2018-10-30    94511        950      b       101140   100880
# 10     269397  2018-09-15    94511        950      b       102700   113400
# 11     269398  2018-11-18    94511        950      b       103000   102700
# 12     269399  2018-10-06    94511        950      b       103670   103670
# 13     269400  2018-11-24    94511        950      b       102540   103670
# 14     269403  2018-09-08    94511        950      b        98840   103460
# 15     269407  2018-10-17    94511        950      b       101980   109920
# 16     269912  2018-11-03    94578        936      b       116250   125000
# 17     269925  2018-10-24    94578        936      b       123500   127600
# 18     270750  2018-11-18    94670        959      g       118520   112400
# 19     271067  2018-09-17    94702       1134      g       145884   140500
# 20     271071  2018-09-11    94702       1134      g       158370   151900
# 21     271077  2018-10-06    94702       1134      g       151800   147420
# 22     271078  2018-10-16    94702       1134      g       145690   147420
# 23     271079  2018-10-09    94702       1134      g       139700   139700
# 24     271080  2018-09-15    94702       1134      g       163600   153000
# 25     271087  2018-09-08    94702       1134      g       154700   154700
# 26     271094  2018-09-17    94705       1134      b       116934   118800
# 27     271098  2018-09-11    94705       1134      b       127400   121300
# 28     271099  2018-10-02    94705       1134      b       121400   121300
# 29     271105  2018-10-06    94705       1134      b       116100   115650
# ...       ...         ...      ...        ...    ...          ...      ...
# 70566  577192  2019-08-24   232844        920      B        69804    69804
# 70567  577193  2019-08-24   232845        920      B        73956    73956
# 70568  577194  2019-08-24   232846        920      B        75613    75613
# 70569  577195  2019-08-24   232847        920      B        76603    76603
# 70570  577196  2019-08-24   232848        920      G        79989    79989
# 70571  577197  2019-08-24   232849        920      G        81638    81638
# 70572  577198  2019-08-24   232850        920      G        83744    83744
# 70573  577199  2019-08-24   232851        920      G        89659    89659
# 70574  577200  2019-08-24   232852        920      G        92661    92661
# 70575  577201  2019-08-24   232853        920      G        94077    94077
# 70576  577202  2019-08-24   232854        920      G        74214    74214
# 70577  577203  2019-08-24   232855        920      G        74371    74371
# 70578  577204  2019-08-24   232856        920      G        74593    74593
# 70579  577205  2019-08-24   232857        920      G        91225    91225
# 70580  577206  2019-08-27   232914       1117      G       106396   106396
# 70581  577207  2019-08-27   232916       1117      G        96840    96840
# 70582  577208  2019-08-23   233003       1285      G       107800   107800
# 70583  577209  2019-08-23   233004       1285      B       123900   123900
# 70584  577210  2019-08-23   233005       1285      B       102200   102200
# 70585  577211  2019-08-23   233006       1285      B        84000    84000
# 70586  577212  2019-08-23   233007       1285      B       139900   139900
# 70587  577213  2019-08-23   233008       1285      B        81900    81900
# 70588  577214  2019-08-23   233009       1285      B        80900    80900
# 70589  577215  2019-08-23   233010       1285      B        72100    72100
# 70590  577216  2019-08-23   233011       1285      B        88900    88900
# 70591  577217  2019-08-23   233012       1285      G       100000   100000
# 70592  577218  2019-08-23   233013       1285      G       115900   115900
# 70593  577219  2019-08-28   233018        923      B        76800    76800
# 70594  577220  2019-08-28   233019        923      B        81300    81300
# 70595  577221  2019-08-27   233020       1167      G       153000   153000
#
#        previous_time  last_year_time improvement_flag pr_flag  goal_time  \
# 0             132000          132000                1       1   123000.0
# 1              90400           90400                1       1    85500.0
# 2             145800               0                0       0   156000.0
# 3             168400               0                1       0   150000.0
# 4              88000               0                0       0   159000.0
# 5             122190          122190                0       0   119900.0
# 6              85120               0                1       1    74500.0
# 7                  0               0                0       0   108500.0
# 8             108410          107890                1       1   101900.0
# 9             100880          108410                1       0    98900.0
# 10            113400               0                1       1   107900.0
# 11            102700               0                0       0    99000.0
# 12                 0               0                0       0   101900.0
# 13            103670               0                1       1   100500.0
# 14            103460          103460                1       1   101000.0
# 15            109920          109920                1       1   107600.0
# 16            125000               0                1       1   124900.0
# 17            127600               0                1       1   132000.0
# 18            116100          113340                0       0    51300.0
# 19            140500               0                0       0   150000.0
# 20            157100               0                0       0   147000.0
# 21            147420          149200                0       0   151500.0
# 22            151800          147420                1       1   156000.0
# 23                 0               0                0       0   144000.0
# 24            153000               0                0       0   151500.0
# 25                 0               0                0       0   144000.0
# 26            118800               0                1       1   113900.0
# 27            122500               0                0       0   119900.0
# 28            127400          122500                1       0   121200.0
# 29            115650          117700                1       0   115000.0
# ...              ...             ...              ...     ...        ...
# 70566              0               0                0       0        NaN
# 70567              0               0                0       0        NaN
# 70568              0               0                0       0        NaN
# 70569              0               0                0       0        NaN
# 70570              0               0                0       0        NaN
# 70571              0               0                0       0        NaN
# 70572              0               0                0       0        NaN
# 70573              0               0                0       0        NaN
# 70574              0               0                0       0        NaN
# 70575              0               0                0       0        NaN
# 70576              0               0                0       0        NaN
# 70577              0               0                0       0        NaN
# 70578              0               0                0       0        NaN
# 70579              0               0                0       0        NaN
# 70580              0               0                0       0        NaN
# 70581              0               0                0       0        NaN
# 70582              0               0                0       0        NaN
# 70583              0               0                0       0        NaN
# 70584              0               0                0       0        NaN
# 70585              0               0                0       0        NaN
# 70586              0               0                0       0        NaN
# 70587              0               0                0       0        NaN
# 70588              0               0                0       0        NaN
# 70589              0               0                0       0        NaN
# 70590              0               0                0       0        NaN
# 70591              0               0                0       0        NaN
# 70592              0               0                0       0        NaN
# 70593              0               0                0       0        NaN
# 70594              0               0                0       0        NaN
# 70595              0               0                0       0        NaN
#
#        goal_flag  course_id  distance  grade_number  run_before
# 0            0.0         80       293             1           1
# 1            0.0        139       190             1           1
# 2            0.0        897       310             1           1
# 3            0.0        902       310             1           1
# 4            0.0        912       194             1           1
# 5            0.0         62       300             1           1
# 6            0.0          1       210             1           1
# 7            0.0          3       310             1           0
# 8            0.0          5       295             1           1
# 9            0.0          5       295             1           1
# 10           0.0          8       300             1           1
# 11           0.0          8       300             1           1
# 12           0.0          9       310             1           0
# 13           0.0          9       310             1           1
# 14           0.0         80       293             1           1
# 15           0.0        514       310             1           1
# 16           0.0         99       300             1           1
# 17           0.0        458       310             1           1
# 18           0.0          8       300             1           1
# 19           0.0        897       310             1           1
# 20           0.0        902       310             1           1
# 21           0.0        906       310             1           1
# 22           0.0        906       310             1           1
# 23           0.0        937       310             1           0
# 24           0.0       1112       310             1           1
# 25           0.0       1549       310             1           0
# 26           0.0        897       310             1           1
# 27           0.0        902       310             1           1
# 28           0.0        902       310             1           1
# 29           0.0        906       310             1           1
# ...          ...        ...       ...           ...         ...
# 70566        NaN        792       200             4           0
# 70567        NaN        792       200             4           0
# 70568        NaN        792       200             4           0
# 70569        NaN        792       200             3           0
# 70570        NaN        792       200             4           0
# 70571        NaN        792       200             3           0
# 70572        NaN        792       200             4           0
# 70573        NaN        792       200             4           0
# 70574        NaN        792       200             3           0
# 70575        NaN        792       200             4           0
# 70576        NaN        792       200             4           0
# 70577        NaN        792       200             4           0
# 70578        NaN        792       200             4           0
# 70579        NaN        792       200             4           0
# 70580        NaN       1166       200             1           0
# 70581        NaN       1166       200             4           0
# 70582        NaN       1416       200             1           0
# 70583        NaN        458       310             2           0
# 70584        NaN       1416       200             3           0
# 70585        NaN       1416       200             3           0
# 70586        NaN       1416       200             4           0
# 70587        NaN       1416       200             4           0
# 70588        NaN       1416       200             4           0
# 70589        NaN       1416       200             4           0
# 70590        NaN       1416       200             3           0
# 70591        NaN       1416       200             3           0
# 70592        NaN       1416       200             3           0
# 70593        NaN       1770       200             2           0
# 70594        NaN       1770       200             2           0
# 70595        NaN       1771       310             1           0
#
# [70596 rows x 17 columns]

# %%
# Change gender to all lowercase
results_df["gender"] = results_df['gender'].str.lower()

# %%
# Add month and year from meet_date
def get_year(x):
    return int(str(x).split('-')[0])
results_df['year'] = results_df['meet_date'].apply(get_year)

def get_month(x):
    return int(str(x).split('-')[1])
results_df['month'] = results_df['meet_date'].apply(get_month)

results_df.head()
# Out:
#        id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 0  264126  2018-09-08    93505       1068      b       117810   132000
# 1  264137  2018-08-17    93505       1068      b        83900    90400
# 2  268859  2018-09-17    94440       1134      b       158302   145800
# 3  268862  2018-09-11    94440       1134      b       165330   140800
# 4  268870  2018-10-02    94440       1134      b       145560    86500
#
#    previous_time  last_year_time improvement_flag pr_flag  goal_time  \
# 0         132000          132000                1       1   123000.0
# 1          90400           90400                1       1    85500.0
# 2         145800               0                0       0   156000.0
# 3         168400               0                1       0   150000.0
# 4          88000               0                0       0   159000.0
#
#    goal_flag  course_id  distance  grade_number  run_before  year  month
# 0        0.0         80       293             1           1  2018      9
# 1        0.0        139       190             1           1  2018      8
# 2        0.0        897       310             1           1  2018      9
# 3        0.0        902       310             1           1  2018      9
# 4        0.0        912       194             1           1  2018     10

# %%
# Determine course_id of state meet (held on 11/24/2018) 
# woodward_park = results_df.loc[results_df["meet_date"] == "2018-11-24"].sort_values("race_result", ascending=True)
# woodward_park.head()
# Woodward Park is course_id = 9



#races = results_df.groupby(['datetime', 'course_id',"distance"]).min()["race_result"].reset_index()
#races = results_df.groupby(['datetime', 'course_id','distance']).nunique()["runr_id"].reset_index()
#races = races.sort_values(["datetime", "course_id","distance"], ascending=[True, True, False]).reset_index()
#races = races.reset_index()
#reset_index()
#races = races.rename(columns={"index":"race_id"})

#results_df
results_df.head(5)

#print(races)
# Out:
#        id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 0  264126  2018-09-08    93505       1068      b       117810   132000
# 1  264137  2018-08-17    93505       1068      b        83900    90400
# 2  268859  2018-09-17    94440       1134      b       158302   145800
# 3  268862  2018-09-11    94440       1134      b       165330   140800
# 4  268870  2018-10-02    94440       1134      b       145560    86500
#
#    previous_time  last_year_time improvement_flag pr_flag  goal_time  \
# 0         132000          132000                1       1   123000.0
# 1          90400           90400                1       1    85500.0
# 2         145800               0                0       0   156000.0
# 3         168400               0                1       0   150000.0
# 4          88000               0                0       0   159000.0
#
#    goal_flag  course_id  distance  grade_number  run_before  year  month
# 0        0.0         80       293             1           1  2018      9
# 1        0.0        139       190             1           1  2018      8
# 2        0.0        897       310             1           1  2018      9
# 3        0.0        902       310             1           1  2018      9
# 4        0.0        912       194             1           1  2018     10

# %%
results_df["datetime"] = pd.to_datetime(results_df['meet_date']) #required to use < or > on date
results_df = results_df.sort_values(['datetime','course_id','distance','race_result'])
results_df.head()
# Out:
#            id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 25635  452528  2018-08-13   148563       1055      b       114900   114900
# 25643  452550  2018-08-13   148565       1055      b       129700   129700
# 44419  500421  2018-08-13   170873       1055      b       130700   130700
# 11961  372428  2018-08-13   122790       1055      b       135700   135700
# 27023  457323  2018-08-13   149470       1055      b       149700   149700
#
#        previous_time  last_year_time improvement_flag pr_flag  goal_time  \
# 25635              0               0                0       0        NaN
# 25643              0               0                0       0        NaN
# 44419              0               0                0       0        NaN
# 11961              0               0                0       0        NaN
# 27023              0               0                0       0        NaN
#
#        goal_flag  course_id  distance  grade_number  run_before  year  month  \
# 25635        NaN        675       310             3           0  2018      8
# 25643        NaN        675       310             3           0  2018      8
# 44419        NaN        675       310             3           0  2018      8
# 11961        NaN        675       310             2           0  2018      8
# 27023        NaN        675       310             3           0  2018      8
#
#         datetime
# 25635 2018-08-13
# 25643 2018-08-13
# 44419 2018-08-13
# 11961 2018-08-13
# 27023 2018-08-13

# %%
all_races_winners = results_df.groupby(['datetime', 'course_id',"distance","gender"]).first().reset_index()
all_races_winners.head()
# Out:
#     datetime  course_id  distance gender      id   meet_date  runr_id  \
# 0 2018-08-13        675       310      b  452528  2018-08-13   148563
# 1 2018-08-13        675       310      g  457335  2018-08-13   149471
# 2 2018-08-17        139       190      b  273987  2018-08-17    94995
# 3 2018-08-17        139       190      g  286529  2018-08-17    97559
# 4 2018-08-17        461       200      b  275298  2018-08-17    95111
#
#    school_id  race_result  pr_time  previous_time  last_year_time  \
# 0       1055       114900   114900              0               0
# 1       1055       152900   152900              0               0
# 2       1068        57000    57000              0               0
# 3       1068        68300    68300              0               0
# 4       1075        63300    63100          63100           63100
#
#   improvement_flag pr_flag  goal_time  goal_flag  grade_number  run_before  \
# 0                0       0        NaN        NaN             3           0
# 1                0       0        NaN        NaN             3           0
# 2                0       0    87400.0        0.0             1           0
# 3                0       0    98000.0        0.0             1           0
# 4                0       0   150000.0        0.0             1           1
#
#    year  month
# 0  2018      8
# 1  2018      8
# 2  2018      8
# 3  2018      8
# 4  2018      8

# %%
# Calculate total number of schools and number of runners per school (using Fall 2018 XC season as best dataset)
fall_2018_all_races = results_df.loc[(results_df['datetime']>"2018-07-31") & 
                                       (results_df['datetime']<"2019-01-01")]
school_count = fall_2018_all_races["school_id"].nunique()

school_runner_count_fall_2018 = fall_2018_all_races.groupby(["school_id"]).nunique()["runr_id"].reset_index()
school_runner_count_fall_2018 = school_runner_count_fall_2018.rename(columns = {"runr_id":"runner_count"})
school_runner_count_fall_2018.head()
# Out:
#    school_id  runner_count
# 0          1            87
# 1          2            24
# 2         10           108
# 3        247            52
# 4        816            78

# %%
# Merge total runner count (via school_id) to results_df
results_complete_df = pd.merge(results_df, school_runner_count_fall_2018, how="left", on="school_id")
results_complete_df.sort_values("race_result").head()
# Out:
#            id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 6180   528472  2018-09-05   180149       1250      g            0        0
# 6181   528522  2018-09-05   180156       1250      g            0        0
# 54820  333637  2018-10-24   105285       1157      b        26380    26940
# 54821  429436  2018-10-24   144847       1157      b        26390    27900
# 54822  289354  2018-10-24    97799       1157      b        27120    27820
#
#        previous_time  last_year_time improvement_flag  ... goal_time  \
# 6180               0               0                0  ...       NaN
# 6181               0               0                0  ...       NaN
# 54820          28130           26940                1  ...       NaN
# 54821          27900           28130                1  ...       NaN
# 54822          28240           27820                1  ...   27000.0
#
#        goal_flag  course_id  distance  grade_number  run_before  year  month  \
# 6180         NaN        223       200             4           0  2018      9
# 6181         NaN        223       200             3           0  2018      9
# 54820        NaN       1037       100             1           1  2018     10
# 54821        NaN       1037       100             2           1  2018     10
# 54822        0.0       1037       100             1           1  2018     10
#
#         datetime runner_count
# 6180  2018-09-05         55.0
# 6181  2018-09-05         55.0
# 54820 2018-10-24        165.0
# 54821 2018-10-24        165.0
# 54822 2018-10-24        165.0
#
# [5 rows x 21 columns]

# %%
#State Meet 2018 info for bubble chart (x-runner_id?, y=pace with School Size bubbles and color for male/female)
fall_2018_3mile_races = results_complete_df.loc[(results_complete_df['datetime']>"2018-07-31") & 
                                       (results_complete_df['datetime']<"2019-01-01") & 
                                       (results_complete_df["distance"]>=300)]
state_finals_2018_male = results_complete_df.loc[(results_complete_df['datetime']=="2018-11-24") & 
                                       (results_complete_df['course_id']== 9) & 
                                       (results_complete_df["gender"] == "b")].sort_values("race_result")
state_finals_2018_female = results_complete_df.loc[(results_complete_df['datetime']=="2018-11-24") & 
                                       (results_complete_df['course_id']== 9) & 
                                       (results_complete_df["gender"] == "g")].sort_values("race_result")
state_finals_2018_female.head()
# Out:
#            id   meet_date  runr_id  school_id gender  race_result  pr_time  \
# 68778  468142  2018-11-24   151473        935      g       103940   102970
# 68781  275081  2018-11-24    95102       1034      g       104260   105530
# 68802  270586  2018-11-24    94657        984      g       105480   105520
# 68815  349967  2018-11-24   118253       1140      g       106270   107620
# 68817  524474  2018-11-24   178118       1255      g       106470   107030
#
#        previous_time  last_year_time improvement_flag  ... goal_time  \
# 68778         102970          105590                1  ...       NaN
# 68781         105530               0                1  ...       NaN
# 68802         105520          109930                1  ...       NaN
# 68815         107620          110510                1  ...       NaN
# 68817         108410          108410                1  ...       NaN
#
#        goal_flag  course_id  distance  grade_number  run_before  year  month  \
# 68778        NaN          9       310             2           1  2018     11
# 68781        NaN          9       310             1           1  2018     11
# 68802        NaN          9       310             1           1  2018     11
# 68815        NaN          9       310             2           1  2018     11
# 68817        NaN          9       310             3           1  2018     11
#
#         datetime runner_count
# 68778 2018-11-24        135.0
# 68781 2018-11-24         48.0
# 68802 2018-11-24        100.0
# 68815 2018-11-24         65.0
# 68817 2018-11-24         29.0
#
# [5 rows x 21 columns]

# %%
#Calc number of racers in Fall season 2018
racers_in_races_2018 = fall_2018_all_races.groupby(['meet_date', 'course_id','distance','gender']).nunique()["runr_id"].reset_index()
racers_in_races_2018 = racers_in_races_2018.rename(columns={"runr_id":"racers_in_race"})

#race results with a PR
prs_in_races_2018 = fall_2018_all_races.loc[fall_2018_all_races["pr_flag"] == "1"]


#number of runners per race with PRs
racers_w_prs_in_races_2018 = prs_in_races_2018.groupby(['meet_date', 'course_id','distance', "gender"]).nunique()["runr_id"].reset_index()
racers_w_prs_in_races_2018 = racers_w_prs_in_races_2018.rename(columns={"runr_id":"racers_w_prs"})
#print("racers w prs in 2018", racers_w_prs_in_races_2018.head(5))
#print(racers_in_races_2018.head(10))

#Calculate the percentage of races with PRs
#join racer with prs to all racers in 2018
percent_pr_df = pd.merge(racers_in_races_2018, racers_w_prs_in_races_2018, how="left", on=["meet_date","course_id","distance","gender"])
#print("1st",percent_pr_df.head(5))
#
percent_pr_df["racers_w_prs"] = percent_pr_df['racers_w_prs'].replace(np.nan, 0)
#print("2nd",percent_pr_df.head())
percent_pr_df["percent_prs"] = (percent_pr_df["racers_w_prs"]/ percent_pr_df["racers_in_race"])*100
percent_pr_df = percent_pr_df.reset_index()
percent_pr_df = percent_pr_df.rename(columns={"index":"race_id"})

percent_pr_df.head()
# Out:
#    race_id   meet_date  course_id  distance gender  racers_in_race  \
# 0        0  2018-08-13        675       310      b               5
# 1        1  2018-08-13        675       310      g               5
# 2        2  2018-08-17        139       190      b              66
# 3        3  2018-08-17        139       190      g              62
# 4        4  2018-08-17        461       200      b              48
#
#    racers_w_prs  percent_prs
# 0           0.0     0.000000
# 1           0.0     0.000000
# 2          25.0    37.878788
# 3          17.0    27.419355
# 4          20.0    41.666667

# %%
percent_pr_df.to_sql("all_2018_races",engine)
all_races_winners.to_sql("all_races_winners",engine)
fall_2018_3mile_races.to_sql("fall_2018_3mile_races",engine)
state_finals_2018_male.to_sql("state_finals_2018_male",engine)
state_finals_2018_female.to_sql("state_finals_2018_female",engine)
